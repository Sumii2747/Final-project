# %%
import pandas as pd 
import numpy as np 
import Cleanup

# %%
# define the function to be called later
clean = Cleanup.clean() #calling out the function 'Cleanup'

# %%
df = pd.read_csv("EMD_Reconstructed(i80 0515-0530).csv") #read csv file
df.head()
# Out:
#    Vehicle_ID  Frame_ID  Total_Frames    Global_Time  Local_X    Local_Y  \
# 0           3       613          1153  1113437626200   28.369  67.290627
# 1           3       614          1153  1113437626300   28.370  67.789941
# 2           3       615          1153  1113437626400   28.372  68.303695
# 3           3       616          1153  1113437626500   28.374  68.834859
# 4           3       617          1153  1113437626600   28.375  69.385326
#
#       Global_X     Global_Y  v_Length  v_Width  v_Class     v_Vel     v_Acc  \
# 0  6042851.531  2133134.762      12.8      6.8        2  4.929700  1.064082
# 1  6042851.469  2133135.258      12.8      6.8        2  5.056585  1.453711
# 2  6042851.346  2133136.250      12.8      6.8        2  5.218489  1.758948
# 3  6042851.223  2133137.243      12.8      6.8        2  5.404807  1.938183
# 4  6042851.143  2133137.889      12.8      6.8        2  5.604517  2.024664
#
#    Lane_ID  Preceding  Following  Space_Headway  Time_Headway
# ...

# %%
df = clean.filter_non_zero_values(df) #to remove or filter out any rows that contain non-zero values

# %%
df = clean.filter_by_desired_lanes(df) #keep only the rows in the DataFrame that correspond to the specified lane(s)

# %%
df
# Out:
#          Vehicle_ID  Frame_ID  Total_Frames    Global_Time  Local_X  \
# 74                3       687          1153  1113437633600   28.370
# 75                3       688          1153  1113437633700   28.371
# 76                3       689          1153  1113437633800   28.371
# 77                3       690          1153  1113437633900   28.371
# 78                3       691          1153  1113437634000   28.372
# ...             ...       ...           ...            ...      ...
# 1048570        1757      6959          1386  1113438260800   29.320
# 1048571        1757      6960          1386  1113438260900   29.320
# 1048572        1757      6961          1386  1113438261000   29.320
# 1048573        1757      6962          1386  1113438261100   29.320
# 1048574        1757      6963          1386  1113438261200   29.320
#
#             Local_Y     Global_X     Global_Y  v_Length  v_Width  v_Class  \
# 74       113.540334  6042845.435  2133183.885      12.8      6.8        2
# ...

# %%
df_filtered= clean.remove_lane_change(df) #df_filtered will contain the DataFrame with lane changes removed

# %%
l = ['Vehicle_ID', 'Frame_ID', 'Total_Frames', 'v_Class', 'Lane_ID', 'Preceding', 'Following']
for col in l:
    df_filtered[col] = df_filtered[col].astype(int) #converts all the values to integers

# %%
df_filtered
# Out:
#          Vehicle_ID  Frame_ID  Total_Frames   Global_Time  Local_X  \
# 74                3       687          1153  1.113438e+12   28.370
# 75                3       688          1153  1.113438e+12   28.371
# 76                3       689          1153  1.113438e+12   28.371
# 77                3       690          1153  1.113438e+12   28.371
# 78                3       691          1153  1.113438e+12   28.372
# ...             ...       ...           ...           ...      ...
# 1048570        1757      6959          1386  1.113438e+12   29.320
# 1048571        1757      6960          1386  1.113438e+12   29.320
# 1048572        1757      6961          1386  1.113438e+12   29.320
# 1048573        1757      6962          1386  1.113438e+12   29.320
# 1048574        1757      6963          1386  1.113438e+12   29.320
#
#             Local_Y     Global_X     Global_Y  v_Length  v_Width  v_Class  \
# 74       113.540334  6042845.435  2133183.885      12.8      6.8        2
# ...

# %% [markdown]
# ### Adding two new column(LOcation and time period)

# %%
num_rows = df_filtered.shape[0]
df_filtered["Location"] = ['i80']*num_rows #populates all rows in that column with the value 'i80 on all rows
df_filtered["Period"] = ['5:15PM - 5:30PM']*num_rows #num_rows populates all rows in that column with the value '5:15PM - 5:30PM' on all rows

# %%
df_filtered.to_csv("Cleaned_515_530.csv") #saves the dataset into csv file named "Clean_515_530"
