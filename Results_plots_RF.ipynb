# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
df_rf_5 = pd.read_csv("prediction_rf_5.csv")
df_rf_1 = pd.read_csv("prediction_rf_1.csv")
df_rf_15 = pd.read_csv("prediction_rf_15.csv")
df_rf_2 = pd.read_csv("prediction_rf_2.csv")

# %%
df_rf_5.columns
# Out:
# Index(['Unnamed: 0', 'Vehicle_ID', 'Frame_ID', 'Local_Y', 'v_Length',
#        'v_Width', 'v_Class', 'v_Vel', 'v_Acc', 'Lane_ID', 'Preceding',
#        'Space_Headway', 'Time_Headway', 'Vehicle_ID_preceding',
#        'Local_Y_preceding', 'v_Length_preceding', 'v_Class_preceding',
#        'v_Vel_preceding', 'v_Acc_preceding', 'Lane_ID_preceding',
#        'Space_Headway_preceding', 'Time_Headway_preceding', 'L-F_Pair',
#        'pair_Time_Duration', 'total_pair_duration', 'Space_Gap',
#        'Difference_of_speed', 'nextframesvel', 'nextframeposition',
#        'nextFrameSpacing', 'precnextframesvel', 'predicted_acceleration',
#        'predicted_velocity', 'predicted_spacing'],
#       dtype='object')

# %%
# Step 1: Extract relevant columns
actual_acceleration = df_rf_5['v_Acc']
predicted_acceleration = df_rf_5['predicted_acceleration']

# Step 2: Filter data for reaction time of 0.5 seconds
reaction_time = 0.5  # Replace with the actual reaction time value in seconds
filtered_data = df_rf_5[df_rf_5['pair_Time_Duration'] == reaction_time]

# Extract filtered actual and predicted accelerations
filtered_actual_acceleration = filtered_data['v_Acc']
filtered_predicted_acceleration = filtered_data['predicted_acceleration']

# Step 3: Plot the actual and predicted accelerations
plt.figure(figsize=(10, 6))
plt.plot(filtered_actual_acceleration, label='Actual Acceleration', color="red")
plt.plot(filtered_predicted_acceleration, label='Predicted Acceleration', color="blue")
plt.xlabel('Time Frames')
plt.ylabel('Acceleration')
plt.title(f'Actual vs. Predicted Acceleration for Reaction Time: {reaction_time} seconds')
plt.legend()
plt.show()

# Plots for Velocity for reaction time 0.5 seconds
actual_acceleration_1 = df_rf_5['nextframesvel']
predicted_acceleration_1 = df_rf_5['predicted_velocity']

# Step 2: Filter data for reaction time of 0.5 seconds
reaction_time = 0.5  # Replace with the actual reaction time value in seconds
filtered_data_1 = df_rf_5[df_rf_5['pair_Time_Duration'] == reaction_time]

# Extract filtered actual and predicted accelerations
filtered_actual_acceleration_1 = filtered_data_1['nextframesvel']
filtered_predicted_acceleration_1 = filtered_data_1['predicted_velocity']

# Step 3: Plot the actual and predicted accelerations
plt.figure(figsize=(10, 6))
plt.plot(filtered_actual_acceleration_1, label='Actual Velocity', color="red")
plt.plot(filtered_predicted_acceleration_1, label='Predicted Velocity', color="blue")
plt.xlabel('Time Frames')
plt.ylabel('Actual Velocity')
plt.title(f'Actual vs. Predicted Velocity for Reaction Time: {reaction_time} seconds')
plt.legend()
plt.show()

# Plot for Spacing for reaction time 0.5 seconds
actual_acceleration_2 = df_rf_5['nextFrameSpacing']
predicted_acceleration_2 = df_rf_5['predicted_spacing']

# Step 2: Filter data for reaction time of 0.5 seconds
reaction_time = 0.5  # Replace with the actual reaction time value in seconds
filtered_data_2 = df_rf_5[df_rf_5['pair_Time_Duration'] == reaction_time]

# Extract filtered actual and predicted accelerations
filtered_actual_acceleration_2 = filtered_data_2['nextFrameSpacing']
filtered_predicted_acceleration_2 = filtered_data_2['predicted_spacing']

# Step 3: Plot the actual and predicted accelerations
plt.figure(figsize=(10, 6))
plt.plot(filtered_actual_acceleration_2, label='Actual Spacing', color="red")
plt.plot(filtered_predicted_acceleration_2, label='Predicted Spacing', color="blue")
plt.xlabel('Time Frames')
plt.ylabel('Actual Spacing')
plt.title(f'Actual vs. Predicted Spacing for Reaction Time: {reaction_time} seconds')
plt.legend()
plt.show()

# %%
# Step 1: Extract relevant columns
actual_acceleration = df_rf_1['v_Acc']
predicted_acceleration = df_rf_1['predicted_acceleration']

# Step 2: Filter data for reaction time of 0.5 seconds
reaction_time = 1  # Replace with the actual reaction time value in seconds
filtered_data = df_rf_1[df_rf_1['pair_Time_Duration'] == reaction_time]

# Extract filtered actual and predicted accelerations
filtered_actual_acceleration = filtered_data['v_Acc']
filtered_predicted_acceleration = filtered_data['predicted_acceleration']

# Step 3: Plot the actual and predicted accelerations
plt.figure(figsize=(10, 6))
plt.plot(filtered_actual_acceleration, label='Actual Acceleration',color = "red")
plt.plot(filtered_predicted_acceleration, label='Predicted Acceleration',color = "blue")
plt.xlabel('Time Frames')
plt.ylabel('Acceleration')
plt.title(f'Actual vs. Predicted Acceleration for Reaction Time: {reaction_time} seconds')
plt.legend()
plt.show()

# Plots for Velocity fro reaction time 1sec
actual_acceleration_1 = df_rf_1['nextframesvel']
predicted_acceleration_1 = df_rf_1['predicted_velocity']

# Step 2: Filter data for reaction time of 0.5 seconds
reaction_time = 1  # Replace with the actual reaction time value in seconds
filtered_data_1 = df_rf_1[df_rf_1['pair_Time_Duration'] == reaction_time]

# Extract filtered actual and predicted accelerations
filtered_actual_acceleration_1 = filtered_data_1['nextframesvel']
filtered_predicted_acceleration_1 = filtered_data_1['predicted_velocity']

# Step 3: Plot the actual and predicted accelerations
plt.figure(figsize=(10, 6))
plt.plot(filtered_actual_acceleration_1, label='Actual Velocity',color = "red")
plt.plot(filtered_predicted_acceleration_1, label='Predicted Velocity',color = "blue")
plt.xlabel('Time Frames')
plt.ylabel('Actual Velcoity')
plt.title(f'Actual vs. Predicted Velocity for Reaction Time: {reaction_time} seconds')
plt.legend()
plt.show()

# Plot for Spacing for reaction time 1 sec

actual_acceleration_2 = df_rf_1['nextFrameSpacing']
predicted_acceleration_2 = df_rf_1['predicted_spacing']

# Step 2: Filter data for reaction time of 0.5 seconds
reaction_time = 1  # Replace with the actual reaction time value in seconds
filtered_data_2 = df_rf_1[df_rf_1['pair_Time_Duration'] == reaction_time]

# Extract filtered actual and predicted accelerations
filtered_actual_acceleration_2 = filtered_data_2['nextFrameSpacing']
filtered_predicted_acceleration_2 = filtered_data_2['predicted_spacing']

# Step 3: Plot the actual and predicted accelerations
plt.figure(figsize=(10, 6))
plt.plot(filtered_actual_acceleration_2, label='Actual Spacing',color = "red")
plt.plot(filtered_predicted_acceleration_2, label='Predicted Spacing',color = "blue")
plt.xlabel('Time Frames')
plt.ylabel('Actual Spacing')
plt.title(f'Actual vs. Predicted Spacing for Reaction Time: {reaction_time} seconds')
plt.legend()
plt.show()

# %%
# Step 1: Extract relevant columns
actual_acceleration = df_rf_15['v_Acc']
predicted_acceleration = df_rf_15['predicted_acceleration']

# Step 2: Filter data for reaction time of 1.5 seconds
reaction_time = 1.5  # Replace with the actual reaction time value in seconds
filtered_data = df_rf_15[df_rf_15['pair_Time_Duration'] == reaction_time]

# Extract filtered actual and predicted accelerations
filtered_actual_acceleration = filtered_data['v_Acc']
filtered_predicted_acceleration = filtered_data['predicted_acceleration']

# Step 3: Plot the actual and predicted accelerations
plt.figure(figsize=(10, 6))
plt.plot(filtered_actual_acceleration, label='Actual Acceleration', color="red")
plt.plot(filtered_predicted_acceleration, label='Predicted Acceleration', color="blue")
plt.xlabel('Time Frames')
plt.ylabel('Acceleration')
plt.title(f'Actual vs. Predicted Acceleration for Reaction Time: {reaction_time} seconds')
plt.legend()
plt.show()

# Plots for Velocity for reaction time 1.5 seconds
actual_acceleration_1 = df_rf_15['nextframesvel']
predicted_acceleration_1 = df_rf_15['predicted_velocity']

# Step 2: Filter data for reaction time of 1.5 seconds
reaction_time = 1.5  # Replace with the actual reaction time value in seconds
filtered_data_1 = df_rf_15[df_rf_15['pair_Time_Duration'] == reaction_time]

# Extract filtered actual and predicted accelerations
filtered_actual_acceleration_1 = filtered_data_1['nextframesvel']
filtered_predicted_acceleration_1 = filtered_data_1['predicted_velocity']

# Step 3: Plot the actual and predicted accelerations
plt.figure(figsize=(10, 6))
plt.plot(filtered_actual_acceleration_1, label='Actual Velocity', color="red")
plt.plot(filtered_predicted_acceleration_1, label='Predicted Velocity', color="blue")
plt.xlabel('Time Frames')
plt.ylabel('Actual Velocity')
plt.title(f'Actual vs. Predicted Velocity for Reaction Time: {reaction_time} seconds')
plt.legend()
plt.show()

# Plot for Spacing for reaction time 1.5 seconds
actual_acceleration_2 = df_rf_15['nextFrameSpacing']
predicted_acceleration_2 = df_rf_15['predicted_spacing']

# Step 2: Filter data for reaction time of 1.5 seconds
reaction_time = 1.5  # Replace with the actual reaction time value in seconds
filtered_data_2 = df_rf_15[df_rf_15['pair_Time_Duration'] == reaction_time]

# Extract filtered actual and predicted accelerations
filtered_actual_acceleration_2 = filtered_data_2['nextFrameSpacing']
filtered_predicted_acceleration_2 = filtered_data_2['predicted_spacing']

# Step 3: Plot the actual and predicted accelerations
plt.figure(figsize=(10, 6))
plt.plot(filtered_actual_acceleration_2, label='Actual Spacing', color="red")
plt.plot(filtered_predicted_acceleration_2, label='Predicted Spacing', color="blue")
plt.xlabel('Time Frames')
plt.ylabel('Actual Spacing')
plt.title(f'Actual vs. Predicted Spacing for Reaction Time: {reaction_time} seconds')
plt.legend()
plt.show()

# %%
# Step 1: Extract relevant columns
actual_acceleration = df_rf_2['v_Acc']
predicted_acceleration = df_rf_2['predicted_acceleration']

# Step 2: Filter data for reaction time of 2 seconds
reaction_time = 2  # Replace with the actual reaction time value in seconds
filtered_data = df_rf_2[df_rf_2['pair_Time_Duration'] == reaction_time]

# Extract filtered actual and predicted accelerations
filtered_actual_acceleration = filtered_data['v_Acc']
filtered_predicted_acceleration = filtered_data['predicted_acceleration']

# Step 3: Plot the actual and predicted accelerations
plt.figure(figsize=(10, 6))
plt.plot(filtered_actual_acceleration, label='Actual Acceleration', color="red")
plt.plot(filtered_predicted_acceleration, label='Predicted Acceleration', color="blue")
plt.xlabel('Time Frames')
plt.ylabel('Acceleration')
plt.title(f'Actual vs. Predicted Acceleration for Reaction Time: {reaction_time} seconds')
plt.legend()
plt.show()

# Plots for Velocity for reaction time 2 seconds
actual_acceleration_1 = df_rf_2['nextframesvel']
predicted_acceleration_1 = df_rf_2['predicted_velocity']

# Step 2: Filter data for reaction time of 2 seconds
reaction_time = 2  # Replace with the actual reaction time value in seconds
filtered_data_1 = df_rf_2[df_rf_2['pair_Time_Duration'] == reaction_time]

# Extract filtered actual and predicted accelerations
filtered_actual_acceleration_1 = filtered_data_1['nextframesvel']
filtered_predicted_acceleration_1 = filtered_data_1['predicted_velocity']

# Step 3: Plot the actual and predicted accelerations
plt.figure(figsize=(10, 6))
plt.plot(filtered_actual_acceleration_1, label='Actual Velocity', color="red")
plt.plot(filtered_predicted_acceleration_1, label='Predicted Velocity', color="blue")
plt.xlabel('Time Frames')
plt.ylabel('Actual Velocity')
plt.title(f'Actual vs. Predicted Velocity for Reaction Time: {reaction_time} seconds')
plt.legend()
plt.show()

# Plot for Spacing for reaction time 2 seconds
actual_acceleration_2 = df_rf_2['nextFrameSpacing']
predicted_acceleration_2 = df_rf_2['predicted_spacing']

# Step 2: Filter data for reaction time of 2 seconds
reaction_time = 2  # Replace with the actual reaction time value in seconds
filtered_data_2 = df_rf_2[df_rf_2['pair_Time_Duration'] == reaction_time]

# Extract filtered actual and predicted accelerations
filtered_actual_acceleration_2 = filtered_data_2['nextFrameSpacing']
filtered_predicted_acceleration_2 = filtered_data_2['predicted_spacing']

# Step 3: Plot the actual and predicted accelerations
plt.figure(figsize=(10, 6))
plt.plot(filtered_actual_acceleration_2, label='Actual Spacing', color="red")
plt.plot(filtered_predicted_acceleration_2, label='Predicted Spacing', color="blue")
plt.xlabel('Time Frames')
plt.ylabel('Actual Spacing')
plt.title(f'Actual vs. Predicted Spacing for Reaction Time: {reaction_time} seconds')
plt.legend()
plt.show()
