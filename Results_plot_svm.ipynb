# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df_svm_5 = pd.read_csv("prediction_svm_5.csv")
df_svm_1 = pd.read_csv("prediction_svm_1.csv")
df_svm_15 = pd.read_csv("prediction_svm_15.csv")
df_svm_2 = pd.read_csv("prediction_svm_2.csv")

# %%
df_svm_5
# Out:
#        Unnamed: 0  Vehicle_ID  Frame_ID     Local_Y  v_Length  v_Width  \
# 0               0        1782      5567   59.774890   5.12064      6.9
# 1               1        1782      5566   57.746729   5.12064      6.9
# 2               2        1782      5568   61.817831   5.12064      6.9
# 3               3        1782      5569   63.871630   5.12064      6.9
# 4               4        1782      5571   67.996026   5.12064      6.9
# ...           ...         ...       ...         ...       ...      ...
# 68965       70253        1747      7275  426.800862   4.51104      6.4
# 68966       70254        1747      7276  428.159937   4.51104      6.4
# 68967       70255        1747      7277  429.522020   4.51104      6.4
# 68968       70256        1747      7278  430.887647   4.51104      6.4
# 68969       70257        1747      7279  432.257350   4.51104      6.4
#
#        v_Class      v_Vel     v_Acc  Lane_ID  ...  total_pair_duration  \
# ...

# %%
# Step 1: Extract relevant columns
actual_acceleration = df_svm_5['v_Acc']
predicted_acceleration = df_svm_5['predicted_acceleration']

# Step 2: Filter data for reaction time of 0.5 seconds
reaction_time = 0.5  # Replace with the actual reaction time value in seconds
filtered_data = df_svm_5[df_svm_5['pair_Time_Duration'] == reaction_time]

# Extract filtered actual and predicted accelerations
filtered_actual_acceleration = filtered_data['v_Acc']
filtered_predicted_acceleration = filtered_data['predicted_acceleration']

# Step 3: Plot the actual and predicted accelerations
plt.figure(figsize=(10, 6))
plt.plot(filtered_actual_acceleration, label='Actual Acceleration', color="red")
plt.plot(filtered_predicted_acceleration, label='Predicted Acceleration', color="blue")
plt.xlabel('Time Frames')
plt.ylabel('Acceleration')
plt.title(f'Actual vs. Predicted Acceleration for Reaction Time: {reaction_time} seconds (SVM)')
plt.legend()
plt.show()

# Plots for Velocity for reaction time 0.5 seconds
actual_acceleration_1 = df_svm_5['v_Vel']
predicted_acceleration_1 = df_svm_5['predicted_velocity']

# Step 2: Filter data for reaction time of 0.5 seconds
reaction_time = 0.5  # Replace with the actual reaction time value in seconds
filtered_data_1 = df_svm_5[df_svm_5['pair_Time_Duration'] == reaction_time]

# Extract filtered actual and predicted accelerations
filtered_actual_acceleration_1 = filtered_data_1['v_Vel']
filtered_predicted_acceleration_1 = filtered_data_1['predicted_velocity']

# Step 3: Plot the actual and predicted accelerations
plt.figure(figsize=(10, 6))
plt.plot(filtered_actual_acceleration_1, label='Actual Velocity', color="red")
plt.plot(filtered_predicted_acceleration_1, label='Predicted Velocity', color="blue")
plt.xlabel('Time Frames')
plt.ylabel('Actual Velocity')
plt.title(f'Actual vs. Predicted Velocity for Reaction Time: {reaction_time} seconds (SVM)')
plt.legend()
plt.show()

# Plot for Spacing for reaction time 0.5 seconds
actual_acceleration_2 = df_svm_5['nextFrameSpacing']
predicted_acceleration_2 = df_svm_5['predicted_spacing']

# Step 2: Filter data for reaction time of 0.5 seconds
reaction_time = 0.5  # Replace with the actual reaction time value in seconds
filtered_data_2 = df_svm_5[df_svm_5['pair_Time_Duration'] == reaction_time]

# Extract filtered actual and predicted accelerations
filtered_actual_acceleration_2 = filtered_data_2['nextFrameSpacing']
filtered_predicted_acceleration_2 = filtered_data_2['predicted_spacing']

# Step 3: Plot the actual and predicted accelerations
plt.figure(figsize=(10, 6))
plt.plot(filtered_actual_acceleration_2, label='Actual Spacing', color="red")
plt.plot(filtered_predicted_acceleration_2, label='Predicted Spacing', color="blue")
plt.xlabel('Time Frames')
plt.ylabel('Actual Spacing')
plt.title(f'Actual vs. Predicted Spacing for Reaction Time: {reaction_time} seconds (SVM)')
plt.legend()
plt.show()

# %%
# Step 1: Extract relevant columns
actual_acceleration = df_svm_1['v_Acc']
predicted_acceleration = df_svm_1['predicted_acceleration']

# Step 2: Filter data for reaction time of 1 second
reaction_time = 1.0  # Replace with the actual reaction time value in seconds
filtered_data = df_svm_1[df_svm_1['pair_Time_Duration'] == reaction_time]

# Extract filtered actual and predicted accelerations
filtered_actual_acceleration = filtered_data['v_Acc']
filtered_predicted_acceleration = filtered_data['predicted_acceleration']

# Step 3: Plot the actual and predicted accelerations
plt.figure(figsize=(10, 6))
plt.plot(filtered_actual_acceleration, label='Actual Acceleration', color="red")
plt.plot(filtered_predicted_acceleration, label='Predicted Acceleration', color="blue")
plt.xlabel('Time Frames')
plt.ylabel('Acceleration')
plt.title(f'Actual vs. Predicted Acceleration for Reaction Time: {reaction_time} seconds (SVM)')
plt.legend()
plt.show()

# Plots for Velocity for reaction time 1 second
actual_acceleration_1 = df_svm_1['v_Vel']
predicted_acceleration_1 = df_svm_1['predicted_velocity']

# Step 2: Filter data for reaction time of 1 second
reaction_time = 1.0  # Replace with the actual reaction time value in seconds
filtered_data_1 = df_svm_1[df_svm_1['pair_Time_Duration'] == reaction_time]

# Extract filtered actual and predicted accelerations
filtered_actual_acceleration_1 = filtered_data_1['v_Vel']
filtered_predicted_acceleration_1 = filtered_data_1['predicted_velocity']

# Step 3: Plot the actual and predicted accelerations
plt.figure(figsize=(10, 6))
plt.plot(filtered_actual_acceleration_1, label='Actual Velocity', color="red")
plt.plot(filtered_predicted_acceleration_1, label='Predicted Velocity', color="blue")
plt.xlabel('Time Frames')
plt.ylabel('Actual Velocity')
plt.title(f'Actual vs. Predicted Velocity for Reaction Time: {reaction_time} seconds (SVM)')
plt.legend()
plt.show()

# Plot for Spacing for reaction time 1 second
actual_acceleration_2 = df_svm_1['nextFrameSpacing']
predicted_acceleration_2 = df_svm_1['predicted_spacing']

# Step 2: Filter data for reaction time of 1 second
reaction_time = 1.0  # Replace with the actual reaction time value in seconds
filtered_data_2 = df_svm_1[df_svm_1['pair_Time_Duration'] == reaction_time]

# Extract filtered actual and predicted accelerations
filtered_actual_acceleration_2 = filtered_data_2['nextFrameSpacing']
filtered_predicted_acceleration_2 = filtered_data_2['predicted_spacing']

# Step 3: Plot the actual and predicted accelerations
plt.figure(figsize=(10, 6))
plt.plot(filtered_actual_acceleration_2, label='Actual Spacing', color="red")
plt.plot(filtered_predicted_acceleration_2, label='Predicted Spacing', color="blue")
plt.xlabel('Time Frames')
plt.ylabel('Actual Spacing')
plt.title(f'Actual vs. Predicted Spacing for Reaction Time: {reaction_time} seconds (SVM)')
plt.legend()
plt.show()

# %%
# Step 1: Extract relevant columns
actual_acceleration = df_svm_15['v_Acc']
predicted_acceleration = df_svm_15['predicted_acceleration']

# Step 2: Filter data for reaction time of 1.5 seconds
reaction_time = 1.5  # Replace with the actual reaction time value in seconds
filtered_data = df_svm_15[df_svm_15['pair_Time_Duration'] == reaction_time]

# Extract filtered actual and predicted accelerations
filtered_actual_acceleration = filtered_data['v_Acc']
filtered_predicted_acceleration = filtered_data['predicted_acceleration']

# Step 3: Plot the actual and predicted accelerations
plt.figure(figsize=(10, 6))
plt.plot(filtered_actual_acceleration, label='Actual Acceleration', color="red")
plt.plot(filtered_predicted_acceleration, label='Predicted Acceleration', color="blue")
plt.xlabel('Time Frames')
plt.ylabel('Acceleration')
plt.title(f'Actual vs. Predicted Acceleration for Reaction Time: {reaction_time} seconds (SVM)')
plt.legend()
plt.show()

# Plots for Velocity for reaction time 1.5 seconds
actual_acceleration_1 = df_svm_15['v_Vel']
predicted_acceleration_1 = df_svm_15['predicted_velocity']

# Step 2: Filter data for reaction time of 1.5 seconds
reaction_time = 1.5  # Replace with the actual reaction time value in seconds
filtered_data_1 = df_svm_15[df_svm_15['pair_Time_Duration'] == reaction_time]

# Extract filtered actual and predicted accelerations
filtered_actual_acceleration_1 = filtered_data_1['v_Vel']
filtered_predicted_acceleration_1 = filtered_data_1['predicted_velocity']

# Step 3: Plot the actual and predicted accelerations
plt.figure(figsize=(10, 6))
plt.plot(filtered_actual_acceleration_1, label='Actual Velocity', color="red")
plt.plot(filtered_predicted_acceleration_1, label='Predicted Velocity', color="blue")
plt.xlabel('Time Frames')
plt.ylabel('Actual Velocity')
plt.title(f'Actual vs. Predicted Velocity for Reaction Time: {reaction_time} seconds (SVM)')
plt.legend()
plt.show()

# Plot for Spacing for reaction time 1.5 seconds
actual_acceleration_2 = df_svm_15['nextFrameSpacing']
predicted_acceleration_2 = df_svm_15['predicted_spacing']

# Step 2: Filter data for reaction time of 1.5 seconds
reaction_time = 1.5  # Replace with the actual reaction time value in seconds
filtered_data_2 = df_svm_15[df_svm_15['pair_Time_Duration'] == reaction_time]

# Extract filtered actual and predicted accelerations
filtered_actual_acceleration_2 = filtered_data_2['nextFrameSpacing']
filtered_predicted_acceleration_2 = filtered_data_2['predicted_spacing']

# Step 3: Plot the actual and predicted accelerations
plt.figure(figsize=(10, 6))
plt.plot(filtered_actual_acceleration_2, label='Actual Spacing', color="red")
plt.plot(filtered_predicted_acceleration_2, label='Predicted Spacing', color="blue")
plt.xlabel('Time Frames')
plt.ylabel('Actual Spacing')
plt.title(f'Actual vs. Predicted Spacing for Reaction Time: {reaction_time} seconds (SVM)')
plt.legend()
plt.show()
